# %%
import sys

# setting path
sys.path.append('../')

import logging
import os
import uuid

from dotenv import load_dotenv

from agentic_writer.graph import AgenticWriter

logging.basicConfig(
    level=logging.INFO,
    force=True,
    format="%(levelname)s:%(name)s:%(filename)s:%(lineno)d:%(message)s",
)

logger = logging.getLogger(__name__)


load_dotenv()
# Out:
# True

# %%
config = {"configurable": {"thread_id": str(uuid.uuid4()),
                            "max_search_depth": 1,
                            "planner_model": "us.anthropic.claude-3-5-haiku-20241022-v1:0",
                            # "writer_model": "us.anthropic.claude-3-5-sonnet-20241022-v2:0",
                            "writer_model": "us.anthropic.claude-3-5-haiku-20241022-v1:0",

                            }}

graph = AgenticWriter(config, tavily_api_key=os.getenv("TAVILY_API_KEY"))

topic = "How to implement aws S3 presigned url post"

reponse = await graph.start(topic)
# Out:
# INFO:root:initial_researcher.py:44:Generating report plan
# INFO:agentic_writer.nodes.initial_researcher:initial_researcher.py:49:Using Configuration: Configuration(report_structure='The report structure should focus on breaking-down the user-provided topic:\n\n1. Introduction (no research needed)\n   - Brief overview of the topic area\n\n2. Main Body Sections:\n   - Each section should focus on a sub-topic of the user-provided topic\n   - Include any key concepts and definitions\n   - Provide real-world examples or case studies where applicable\n\n3. Conclusion\n   - Aim for 1 structural element (either a list of table) that distills the main body sections\n   - Provide a concise summary of the report', writing_guidelines='\n- Strict 200 word limit\n- Start with your most important insight in **bold**\n', number_of_queries=2, max_search_depth=1, planner_model='us.anthropic.claude-3-5-haiku-20241022-v1:0', writer_model='us.anthropic.claude-3-5-sonnet-20241022-v2:0', output_dir='output')
# INFO:agentic_writer.nodes.initial_researcher:initial_researcher.py:66:Generated queries: ['AWS S3 presigned URL POST method implementation best practices', 'S3 presigned POST request security and authentication techniques']
# INFO:httpx:_client.py:1740:HTTP Request: POST https://api.tavily.com/search "HTTP/1.1 200 OK"
# INFO:httpx:_client.py:1740:HTTP Request: POST https://api.tavily.com/search "HTTP/1.1 200 OK"
# INFO:root:article_outline_generator.py:52:Generating report plan
# INFO:agentic_writer.nodes.article_outline_generator:article_outline_generator.py:60:Using Configuration: Configuration(report_structure='The report structure should focus on breaking-down the user-provided topic:\n\n1. Introduction (no research needed)\n   - Brief overview of the topic area\n\n2. Main Body Sections:\n   - Each section should focus on a sub-topic of the user-provided topic\n   - Include any key concepts and definitions\n   - Provide real-world examples or case studies where applicable\n\n3. Conclusion\n   - Aim for 1 structural element (either a list of table) that distills the main body sections\n   - Provide a concise summary of the report', writing_guidelines='\n- Strict 200 word limit\n- Start with your most important insight in **bold**\n', number_of_queries=2, max_search_depth=1, planner_model='us.anthropic.claude-3-5-haiku-20241022-v1:0', writer_model='us.anthropic.claude-3-5-sonnet-20241022-v2:0', output_dir='output')
# INFO:agentic_writer.nodes.article_outline_generator:article_outline_generator.py:78:Generated sections: [Section(section_number=1, name='Introduction to Presigned URL Uploads', description='Overview of presigned URLs and their importance in secure S3 file uploads', research=False, content='Presigned URLs provide a secure method for uploading files to Amazon S3 without requiring direct AWS credentials. This technique allows temporary, controlled access to S3 buckets, enabling secure file uploads for web applications and services.', sources=[]), Section(section_number=2, name='Understanding Presigned URL Mechanics', description='Detailed explanation of how presigned URL POST requests work in AWS S3', research=True, content='', sources=[Source(title='AWS Presigned URL Overview', url='https://docs.aws.amazon.com/prescriptive-guidance/latest/presigned-url-best-practices/overview.html')]), Section(section_number=3, name='Step-by-Step Implementation Guide', description='Practical implementation of presigned URL POST for S3 uploads', research=True, content='', sources=[Source(title='Securing AWS S3 Uploads', url='https://medium.com/@aidan.hallett/securing-aws-s3-uploads-using-presigned-urls-aa821c13ae8d')]), Section(section_number=4, name='Security Best Practices', description='Security considerations and recommendations for presigned URL implementations', research=True, content='', sources=[Source(title='AWS Presigned URL Best Practices', url='https://docs.aws.amazon.com/prescriptive-guidance/latest/presigned-url-best-practices/best-practices.html')]), Section(section_number=5, name='Monitoring and Guardrails', description='Techniques for monitoring and controlling presigned URL usage', research=True, content='', sources=[Source(title='Establishing Guardrails for Presigned URLs', url='https://docs.aws.amazon.com/prescriptive-guidance/latest/presigned-url-best-practices/introduction.html')]), Section(section_number=6, name='Conclusion', description='Summary of key takeaways and best practices for S3 presigned URL posts', research=False, content='Presigned URL POST provides a powerful and secure method for uploading files to S3, offering granular control and temporary access without compromising overall security.', sources=[])]

# %%
from IPython.display import Image, display

display(Image(graph.graph.get_graph(xray=1).draw_mermaid_png()))

# %%
state = graph.get_state()

state.values['title']
state.values['sections']

# %%
feedback = input("Feedback: ")

if feedback == "" or feedback.lower() == "true":
    feedback = True

response = await graph.feedback(feedback)
# Out:
# INFO:agentic_writer.graph:graph.py:84:Feedback received: True
# INFO:httpx:_client.py:1740:HTTP Request: POST https://api.tavily.com/search "HTTP/1.1 200 OK"
# INFO:httpx:_client.py:1740:HTTP Request: POST https://api.tavily.com/search "HTTP/1.1 200 OK"
# INFO:httpx:_client.py:1740:HTTP Request: POST https://api.tavily.com/search "HTTP/1.1 200 OK"
# INFO:httpx:_client.py:1740:HTTP Request: POST https://api.tavily.com/search "HTTP/1.1 200 OK"
# INFO:httpx:_client.py:1740:HTTP Request: POST https://api.tavily.com/search "HTTP/1.1 200 OK"
# INFO:httpx:_client.py:1740:HTTP Request: POST https://api.tavily.com/search "HTTP/1.1 200 OK"
# INFO:httpx:_client.py:1740:HTTP Request: POST https://api.tavily.com/search "HTTP/1.1 200 OK"
# INFO:httpx:_client.py:1740:HTTP Request: POST https://api.tavily.com/search "HTTP/1.1 200 OK"
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID e4e550c9-7c2e-49e0-886f-f243ee231b78.')
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID 58a5950e-7458-4d06-8de2-56e353feea97.')
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID 100fd6d0-353c-4357-93f6-87332d5f3273.')
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID f282a42b-49e2-4580-acb2-3344ecaccc6a.')
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID d6881bba-7119-4e6b-8183-195b1b148bbd.')
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID a5d0bd97-bd73-4ea1-a97c-a167b2979258.')
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID 66c338b1-46c6-485a-8f62-3c884ae109ed.')
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID d1e85034-f68f-4dd7-aad7-4c01ef03a290.')
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID c6cbb8b3-0e7a-4707-8d18-c1957ded02ed.')
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID a0d8d388-da84-4d98-b3d7-c42417649427.')
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID ce88da81-a967-4c66-9f04-52aff53501b1.')
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID 97e0a59c-b80a-4a8e-99ad-8114619978a1.')
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID ddbe6678-534d-4cc4-864d-d2d25c29801f.')
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID ef438007-35b5-46cb-9a24-3e1db027b0be.')
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID bb4ad3ff-65a0-4843-b2f2-deeef27f8622.')
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID 1591d3ed-3782-4908-bc88-fc64e3eb1df2.')
# ERROR:root:bedrock.py:971:Error raised by bedrock service: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# WARNING:langchain_core.callbacks.manager:manager.py:287:Error in LangChainTracer.on_llm_error callback: TracerException('No indexed run ID a72a64c1-5820-4e4d-923b-6542cee2390e.')
# ERROR:agentic_writer.utils:utils.py:34:Execution failed after 5 attempts
# ---------------------------------------------------------------------------
# ThrottlingException                       Traceback (most recent call last)
# Cell In[4], line 6
#       3 if feedback == "" or feedback.lower() == "true":
#       4     feedback = True
# ----> 6 response = await graph.feedback(feedback)
#
# File ~/Documents/artefacts/agentic_writer/notebooks/../agentic_writer/graph.py:86, in AgenticWriter.feedback(self, feedback)
#      82 """Provides feedback to the workflow."""
#      84 logger.info(f"Feedback received: {feedback}")
# ---> 86 return await self.graph.ainvoke(Command(resume=feedback), self.config, stream_mode="updates")
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langgraph/pregel/__init__.py:2177, in Pregel.ainvoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    2175 else:
#    2176     chunks = []
# -> 2177 async for chunk in self.astream(
#    2178     input,
#    2179     config,
#    2180     stream_mode=stream_mode,
#    2181     output_keys=output_keys,
#    2182     interrupt_before=interrupt_before,
#    2183     interrupt_after=interrupt_after,
#    2184     debug=debug,
#    2185     **kwargs,
#    2186 ):
#    2187     if stream_mode == "values":
#    2188         latest = chunk
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langgraph/pregel/__init__.py:2062, in Pregel.astream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    2056 # Similarly to Bulk Synchronous Parallel / Pregel model
#    2057 # computation proceeds in steps, while there are channel updates
#    2058 # channel updates from step N are only visible in step N+1
#    2059 # channels are guaranteed to be immutable for the duration of the step,
#    2060 # with channel updates applied only at the transition between steps
#    2061 while loop.tick(input_keys=self.input_channels):
# -> 2062     async for _ in runner.atick(
#    2063         loop.tasks.values(),
#    2064         timeout=self.step_timeout,
#    2065         retry_policy=self.retry_policy,
#    2066         get_waiter=get_waiter,
#    2067     ):
#    2068         # emit output
#    2069         for o in output():
#    2070             yield o
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langgraph/pregel/runner.py:527, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     525     fut.cancel()
#     526 # panic on failure or timeout
# --> 527 _panic_or_proceed(
#     528     futures.done.union(f for f, t in futures.items() if t is not None),
#     529     timeout_exc_cls=asyncio.TimeoutError,
#     530     panic=reraise,
#     531 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langgraph/pregel/runner.py:619, in _panic_or_proceed(futs, timeout_exc_cls, panic)
#     617         # raise the exception
#     618         if panic:
# --> 619             raise exc
#     620 if inflight:
#     621     # if we got here means we timed out
#     622     while inflight:
#     623         # cancel all pending tasks
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langgraph/pregel/retry.py:128, in arun_with_retry(task, retry_policy, stream, configurable)
#     126         break
#     127     else:
# --> 128         return await task.proc.ainvoke(task.input, config)
#     129 except ParentCommand as exc:
#     130     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langgraph/utils/runnable.py:583, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#     579 config = patch_config(
#     580     config, callbacks=run_manager.get_child(f"seq:step:{i + 1}")
#     581 )
#     582 if i == 0:
# --> 583     input = await step.ainvoke(input, config, **kwargs)
#     584 else:
#     585     input = await step.ainvoke(input, config)
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langgraph/pregel/__init__.py:2177, in Pregel.ainvoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    2175 else:
#    2176     chunks = []
# -> 2177 async for chunk in self.astream(
#    2178     input,
#    2179     config,
#    2180     stream_mode=stream_mode,
#    2181     output_keys=output_keys,
#    2182     interrupt_before=interrupt_before,
#    2183     interrupt_after=interrupt_after,
#    2184     debug=debug,
#    2185     **kwargs,
#    2186 ):
#    2187     if stream_mode == "values":
#    2188         latest = chunk
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langgraph/pregel/__init__.py:2062, in Pregel.astream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    2056 # Similarly to Bulk Synchronous Parallel / Pregel model
#    2057 # computation proceeds in steps, while there are channel updates
#    2058 # channel updates from step N are only visible in step N+1
#    2059 # channels are guaranteed to be immutable for the duration of the step,
#    2060 # with channel updates applied only at the transition between steps
#    2061 while loop.tick(input_keys=self.input_channels):
# -> 2062     async for _ in runner.atick(
#    2063         loop.tasks.values(),
#    2064         timeout=self.step_timeout,
#    2065         retry_policy=self.retry_policy,
#    2066         get_waiter=get_waiter,
#    2067     ):
#    2068         # emit output
#    2069         for o in output():
#    2070             yield o
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langgraph/pregel/runner.py:444, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     442 t = tasks[0]
#     443 try:
# --> 444     await arun_with_retry(
#     445         t,
#     446         retry_policy,
#     447         stream=self.use_astream,
#     448         configurable={
#     449             CONFIG_KEY_SEND: partial(writer, t),
#     450             CONFIG_KEY_CALL: partial(call, t),
#     451         },
#     452     )
#     453     self.commit(t, None)
#     454 except Exception as exc:
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langgraph/pregel/retry.py:128, in arun_with_retry(task, retry_policy, stream, configurable)
#     126         break
#     127     else:
# --> 128         return await task.proc.ainvoke(task.input, config)
#     129 except ParentCommand as exc:
#     130     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langgraph/utils/runnable.py:583, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#     579 config = patch_config(
#     580     config, callbacks=run_manager.get_child(f"seq:step:{i + 1}")
#     581 )
#     582 if i == 0:
# --> 583     input = await step.ainvoke(input, config, **kwargs)
#     584 else:
#     585     input = await step.ainvoke(input, config)
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langgraph/utils/runnable.py:371, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#     369 if ASYNCIO_ACCEPTS_CONTEXT:
#     370     coro = cast(Coroutine[None, None, Any], self.afunc(*args, **kwargs))
# --> 371     ret = await asyncio.create_task(coro, context=context)
#     372 else:
#     373     ret = await self.afunc(*args, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langchain_core/runnables/config.py:588, in run_in_executor(executor_or_config, func, *args, **kwargs)
#     584         raise RuntimeError from exc
#     586 if executor_or_config is None or isinstance(executor_or_config, dict):
#     587     # Use default executor with context copied from current context
# --> 588     return await asyncio.get_running_loop().run_in_executor(
#     589         None,
#     590         cast(Callable[..., T], partial(copy_context().run, wrapper)),
#     591     )
#     593 return await asyncio.get_running_loop().run_in_executor(executor_or_config, wrapper)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.8/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langchain_core/runnables/config.py:579, in run_in_executor.<locals>.wrapper()
#     577 def wrapper() -> T:
#     578     try:
# --> 579         return func(*args, **kwargs)
#     580     except StopIteration as exc:
#     581         # StopIteration can't be set on an asyncio.Future
#     582         # it raises a TypeError and leaves the Future pending forever
#     583         # so we need to convert it to a RuntimeError
#     584         raise RuntimeError from exc
#
# File ~/Documents/artefacts/agentic_writer/notebooks/../agentic_writer/nodes/section_writer.py:173, in SectionWriter.__call__(self, state, config)
#     169 section.content = self._generate_section_content(
#     170     writer_model, section_writer_instructions, section, source_str, writing_guidelines)
#     171 section.sources = sources
# --> 173 feedback = self._grade_section_content(
#     174     writer_model, section_grader_instructions, section)
#     176 if feedback.grade == "pass" or state["search_iterations"] >= configurable.max_search_depth:
#     177     # Publish the section to completed sections
#     178     return Command(
#     179         update={"completed_sections": [section]},
#     180         goto=END
#     181     )
#
# File ~/Documents/artefacts/agentic_writer/notebooks/../agentic_writer/utils.py:36, in exponential_backoff_retry.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      33 if attempt == max_retries:
#      34     logger.error(
#      35         f"Execution failed after {attempt} attempts")
# ---> 36     raise e
#      38 # Add jitter to avoid thundering herd problem
#      39 jitter = random.uniform(0, 0.1 * delay)
#
# File ~/Documents/artefacts/agentic_writer/notebooks/../agentic_writer/utils.py:29, in exponential_backoff_retry.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      27 for attempt in range(max_retries + 1):
#      28     try:
# ---> 29         return func(*args, **kwargs)
#      31     except ExceptionToCheck as e:
#      33         if attempt == max_retries:
#
# File ~/Documents/artefacts/agentic_writer/notebooks/../agentic_writer/nodes/section_writer.py:212, in SectionWriter._grade_section_content(self, model, system_prompt, section)
#     208 section_grader_instructions_formatted = system_prompt.format(
#     209     section_topic=section.description, section=section.content)
#     211 structured_llm = model.with_structured_output(Feedback)
# --> 212 feedback = structured_llm.invoke([SystemMessage(content=section_grader_instructions_formatted)]+[
#     213     HumanMessage(content="Grade the article and consider follow-up questions for missing information:")])
#     215 return feedback
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langchain_core/runnables/base.py:3022, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3020 context.run(_set_config_context, config)
#    3021 if i == 0:
# -> 3022     input = context.run(step.invoke, input, config, **kwargs)
#    3023 else:
#    3024     input = context.run(step.invoke, input, config)
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langchain_core/runnables/base.py:5360, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5354 def invoke(
#    5355     self,
#    5356     input: Input,
#    5357     config: Optional[RunnableConfig] = None,
#    5358     **kwargs: Optional[Any],
#    5359 ) -> Output:
# -> 5360     return self.bound.invoke(
#    5361         input,
#    5362         self._merge_configs(config),
#    5363         **{**self.kwargs, **kwargs},
#    5364     )
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:284, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     273 def invoke(
#     274     self,
#     275     input: LanguageModelInput,
#    (...)
#     279     **kwargs: Any,
#     280 ) -> BaseMessage:
#     281     config = ensure_config(config)
#     282     return cast(
#     283         ChatGeneration,
# --> 284         self.generate_prompt(
#     285             [self._convert_input(input)],
#     286             stop=stop,
#     287             callbacks=config.get("callbacks"),
#     288             tags=config.get("tags"),
#     289             metadata=config.get("metadata"),
#     290             run_name=config.get("run_name"),
#     291             run_id=config.pop("run_id", None),
#     292             **kwargs,
#     293         ).generations[0][0],
#     294     ).message
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:860, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     852 def generate_prompt(
#     853     self,
#     854     prompts: list[PromptValue],
#    (...)
#     857     **kwargs: Any,
#     858 ) -> LLMResult:
#     859     prompt_messages = [p.to_messages() for p in prompts]
# --> 860     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:690, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     687 for i, m in enumerate(messages):
#     688     try:
#     689         results.append(
# --> 690             self._generate_with_cache(
#     691                 m,
#     692                 stop=stop,
#     693                 run_manager=run_managers[i] if run_managers else None,
#     694                 **kwargs,
#     695             )
#     696         )
#     697     except BaseException as e:
#     698         if run_managers:
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:925, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     923 else:
#     924     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 925         result = self._generate(
#     926             messages, stop=stop, run_manager=run_manager, **kwargs
#     927         )
#     928     else:
#     929         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langchain_aws/chat_models/bedrock.py:548, in ChatBedrock._generate(self, messages, stop, run_manager, **kwargs)
#     546 if provider == "anthropic":
#     547     stream_iter = self._stream(messages, stop, run_manager, **kwargs)
# --> 548     return generate_from_stream(stream_iter)
#     550 response_metadata: List[Dict[str, Any]] = []
#     551 for chunk in self._stream(messages, stop, run_manager, **kwargs):
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:87, in generate_from_stream(stream)
#      78 def generate_from_stream(stream: Iterator[ChatGenerationChunk]) -> ChatResult:
#      79     """Generate from a stream.
#      80
#      81     Args:
#    (...)
#      85         ChatResult: Chat result.
#      86     """
# ---> 87     generation = next(stream, None)
#      88     if generation:
#      89         generation += list(stream)
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langchain_aws/chat_models/bedrock.py:485, in ChatBedrock._stream(self, messages, stop, run_manager, **kwargs)
#     480 else:
#     481     prompt = ChatPromptAdapter.convert_messages_to_prompt(
#     482         provider=provider, messages=messages, model=self._get_model()
#     483     )
# --> 485 for chunk in self._prepare_input_and_invoke_stream(
#     486     prompt=prompt,
#     487     system=system,
#     488     messages=formatted_messages,
#     489     stop=stop,
#     490     run_manager=run_manager,
#     491     **kwargs,
#     492 ):
#     493     if isinstance(chunk, AIMessageChunk):
#     494         generation_chunk = ChatGenerationChunk(message=chunk)
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langchain_aws/llms/bedrock.py:974, in BedrockBase._prepare_input_and_invoke_stream(self, prompt, system, messages, stop, run_manager, **kwargs)
#     972     if run_manager is not None:
#     973         run_manager.on_llm_error(e)
# --> 974     raise e
#     976 for chunk in LLMInputOutputAdapter.prepare_output_stream(
#     977     provider,
#     978     response,
#    (...)
#     981     coerce_content_to_string=coerce_content_to_string,
#     982 ):
#     983     yield chunk
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/langchain_aws/llms/bedrock.py:968, in BedrockBase._prepare_input_and_invoke_stream(self, prompt, system, messages, stop, run_manager, **kwargs)
#     965         request_options["trace"] = "ENABLED"
#     967 try:
# --> 968     response = self.client.invoke_model_with_response_stream(**request_options)
#     970 except Exception as e:
#     971     logging.error(f"Error raised by bedrock service: {e}")
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/botocore/client.py:569, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     565     raise TypeError(
#     566         f"{py_operation_name}() only accepts keyword arguments."
#     567     )
#     568 # The "self" in this scope is referring to the BaseClient.
# --> 569 return self._make_api_call(operation_name, kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/agentic-writer-v6PMjlbt-py3.12/lib/python3.12/site-packages/botocore/client.py:1023, in BaseClient._make_api_call(self, operation_name, api_params)
#    1019     error_code = error_info.get("QueryErrorCode") or error_info.get(
#    1020         "Code"
#    1021     )
#    1022     error_class = self.exceptions.from_code(error_code)
# -> 1023     raise error_class(parsed_response, operation_name)
#    1024 else:
#    1025     return parsed_response
#
# ThrottlingException: An error occurred (ThrottlingException) when calling the InvokeModelWithResponseStream operation (reached max retries: 4): Too many requests, please wait before trying again.
# During task with name 'section_write' and id 'cc41e6c1-cd06-56b1-9e92-f8d769df03d3'
# During task with name 'build_section_with_web_research' and id 'd052bc21-ca4c-e477-107e-7dff218cdb21'

# %%
response

# %%
state = graph.get_state()

state.values['sections']

# %%
state.values['completed_sections']

# %%
print(state.values['report_sections_from_research'])

# %%
from IPython.display import Markdown
state = graph.get_state()

Markdown(state.values["final_report"])
